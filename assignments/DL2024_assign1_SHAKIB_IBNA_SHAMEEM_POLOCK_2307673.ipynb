# %% [markdown]
# # Deep Learning 2024 - Assignment 1
#
# Designed by Marko Savic (marko.savic@oulu.fi)

# %% [markdown]
# ## Outline (10 points)
# #### Submission:
# We will give 2 weeks for each assignment and more for the final project.
#
# The grades will be released after the deadline. Please also put your name and student number (if you have one) in the file name of the returned assignments. (DL2024_assign1_NAME_SURNAME_STUDENTNUMBER.ipynb)
#
# #### In this assignment, you will learn:
# * How to load data and create a train/test split
# * How to build your own Pytorch model for simple linear regression problem on the generated data.
# * Training the model with gradient descent algorithm in Pytorch.
# * Simple visualisation of data, loss and linear model
#
# #### Tasks (10 points):
# * Part 1. Load dataset and split into training and testing sets (1.5 points)
# * Part 2.1 Model (1.5 points)
# * Part 2.2 Training (7 points)
#
# #### Environment
# Python 3 + Pytorch (>=1.3).<br>
# Other libraries should be installed correctly such as numpy, matplotlib, *etc*., according to the dependencies of the assignment. <br>
# If you haven’t installed Pytorch and Jupyter notebook in your computer, an alternative environment to finish the assignment is CSC notebook: [`https://noppe.2.rahtiapp.fi/`](https://noppe.2.rahtiapp.fi/) -> log in with HaKa using your university account -> Jupyter Machine Learning.
# Also, googlecolab is available through your google university account (instruction in https://www.oulu.fi/en/for-students/supporting-your-studies-and-contact-information-for-students/it-services-for-students/google-workspace-for-education). Computer room TS135 contains computers with GPUs that you can utilise as well.
#
# We will give 2 weeks for each assignment and more for the final project. So it may happen where the new assignment is published before the deadline of the previous assignment. Please do not wait till the last minute to complete the assigments, as they can be time consuming.
#
# #### Database
# * Advertising dataset
#
# #### Hints
# * To find the place where you have to insert your solution, hit Crtl + F and search for **TODO:** . You are not supposed to modify the code from other parts.
# * Be careful with the shape of the weights, gradient, .. of your tensor in your implementation. Double check and make sure the shapes fit for computation, especially matrix multiplication.
# * Use only torch functions for the model, and avoid iterations. E.g. if you put a for cycle in the model function then parallelism is gone and your model will not run efficiently on GPUs. Also once you have the data loaded as tensors, you need to use torch functions, if you convert to numpy arrays in the training loop then it will not train efficiently.
# * Check the examples from the pytorch tutorial lecture, they can help understand the assignment better.

# %% [markdown]
# ## Part 1. Load dataset and split into training and testing sets
#
# Suppose we observe a set of n real-valued input variables x = $\{x_n\}$ and wish to use this observation to predict
# the value of a real-valued target variable $y$. In the tutorial we considered artifical examples with synthetic data. In this exercise we will consider a simple dataset that is suitable for linear regression.
#
# We will take a small advertisement dataset. It contains data on the budget allocated for TV, radio and newspaper advertisements with the resulting sales. It contains n = 200 samples with three variables "TV", "Radio","Newspaper" and the value we want to predict, that is "Sales". Assuming a linear model is a good representation of the correlation between advertisement budgets and final sales, we will try to train a linear model to regress the sales based on advertisement budget.
#
# The dataset is located in the advertisement .csv file and opened as a pandas Dataframe. Firstly we will turn the input variables and regression target into Tensors, and then split the data into training and testing sets. In this case we choose a five fold split, meaning we will use 20% of the data for testing (last 40 samples) and 80% for training (first 160 samples).
#
# Please create the required training and testing data below and plot the relationship between the feature 'TV' and the target. Since we have 3 different features, we will only pick 'TV' a 2D plot.

# %%
# !pip install onedrivedownloader

from onedrivedownloader import download
import os
link = 'https://unioulu-my.sharepoint.com/:x:/g/personal/msavic21_univ_yo_oulu_fi/Eb211jNyQAVIhTq1HsoxQyEBEqoDNHhr606Kfh9LY5Brjw?e=cONlaG'

#if not os.path.exists('./data/fashion_mnist_npy'):
#    print('Downloading dataset')
download(link, filename="./advertising.csv", unzip=True, unzip_path='./')
# Out:
# 100%|██████████| 4.06k/4.06k [00:00<00:00, 1.42MiB/s]
# './advertising.csv'

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
import torch
import numpy as np
import pandas as pd 

adv_dataset=pd.read_csv('./advertising.csv')
adv_dataset.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# TODO: (1.5 points, details are given below): 

# get the relevant data from the adv_dataset dataframe and assign them to the Tensors x (feature variables) and y (target)  (0.5 point)
# YOUR CODE HERE

x = adv_dataset[['TV', 'Radio', 'Newspaper']].values
y = adv_dataset[['Sales']].values

x = torch.tensor(x, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32)
y = y.squeeze()

print(x.size(),y.size())

# divide the data in a train set (80% of the data) and test set (20% of the data). Resulting in x_train, x_test, y_train, y_test (0.5 point)
# YOUR CODE HERE
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
y_train = y_train.squeeze()
y_test = y_test.squeeze()

print(x_train.size(),y_train.size())
print(x_test.size(),y_test.size())


# plot the first feature 'TV' in relationship with the target y. Train and test data should be in a single figure with two different colors (0.5 point)
# YOUR CODE HERE
plt.scatter(x_train[:,0], y_train, color='blue', label = 'train_data')
plt.scatter(x_test[:,0], y_test, color='red',label = 'test_data')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.legend()
plt.show()
# Out:
# torch.Size([200, 3]) torch.Size([200])
# torch.Size([160, 3]) torch.Size([160])
# torch.Size([40, 3]) torch.Size([40])

# %% [markdown]
# ## Part 2. Solving the linear regression problem in Pytorch using Gradient Descent Algorithm
# Congratulations you have prepared the data correctly! Now we will move onto creating our model and training it.

# %% [markdown]
# ### 2.1 Model
# In this part, you will define your own model class. To do that, you have to remember the following rules:
# 1. The model class should be inherited from [`nn.Module`](https://pytorch.org/docs/stable/generated/torch.nn.Module.html#torch.nn.Module);
# 2. Re-write the **\_\_init\_\_** function and the **forward** function;
# 3. In the **\_\_init\_\_** function, you should always call the parent's **\_\_init\_\_** function first.
# 4. Don't use the nn.Linear() layer, implement it yourself.
# 5. Use 1 tensor to define w (not 3) and 1 tensor to define b.
# 6. Only torch functions and no iterations inside the model.
#
# To make it simpler, since we are using a linear function to approximate the phenomenon that generated the data, our function will be:
#
# \begin{align*}
# y = w^T x + b
# \end{align*}
#
# Therefore, in the model, we need to set 2 parameters: $w$, $b$

# %%
# TODO (1.5 points, details are given below)
import torch.nn as nn
import numpy as np

# define a class (0.5) + write the __init__ function (0.5 point) + write the forward function (0.5 points)

# YOUR CODE HERE

class CustomLinearModel(nn.Module):
    def __init__(self, input_dim):
        super(CustomLinearModel, self).__init__()
        
        
        self.w = nn.Parameter(torch.randn(input_dim, 1))  
        self.b = nn.Parameter(torch.randn(1))            

    def forward(self, x):
        y = torch.matmul(x, self.w) + self.b
        return y

# %% [markdown]
# ### 2.2 Training
# Here, you will train your model based on the training data and evaluate the model on testing data.
# 1. Set proper number of iterations and learning rate.
# 2. Remember to use a proper optimizer (you may have many choices: Adam, SGD, RMSprop, ... please find the detailed information in https://pytorch.org/docs/stable/optim.html and know how to use them).
# 3. In order to train the model, a loss function should be defined:
# \begin{align*}
# loss = \frac{1}{N}\sum_{i=1}^{N}|f_i - y_i|,
# \end{align*}
# where, $f_i$ is the output of the model and $N$ is the number of training data pairs.
# 4. The model must be trained only using training data.
# 5. Remember to clear the old gradients of parameters before a new backward propagation.
# 6. In every certain number of iterations, print the values of the parameters, the training loss, and the testing loss.
# 7. Meanwhile, please track the training loss and the testing loss in each iteration. Once the training is done, the curves of losses should be plotted (two curves are drawn in the same figure, where x axis indicates iterations and y axis indicates the losses).
# 8. Lastly, draw all the training data, testing data and the curve of the trained model in the same figure (use different showing styles to distinguish them).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt


# make an instance of the model class (0.5 point)  
input_dim = x_train.shape[1]
model = CustomLinearModel(input_dim)

# mreate an optimizer, set a workable learning rate (1 point)
learning_rate = 0.001
optimizer = optim.AdamW(model.parameters(), lr=learning_rate)


training_losses = []
testing_losses = []

n_itr = 10000

for i in range(n_itr):

    # Train
    # forward propagation 
    model.train()  # Change model to train mode
    
    # calculate the output of model (0.5 point)
    y_pred_train = model(x_train)
    
    # calculate loss according to the above equation (1 point)
    
    loss = torch.mean(torch.abs(y_pred_train - y_train))
    training_losses.append(loss.item())

    # backward propagation (clear old gradients, calculate gradients of parameters, gradient descent algorithm) (1.5 point)
    optimizer.zero_grad()      
    loss.backward()            
    optimizer.step()        

    # evaluate, calculate the testing loss (1 point)
    model.eval()  # Change model to eval mode
    with torch.no_grad():
        y_pred_test = model(x_test)
        test_loss = torch.mean(torch.abs(y_pred_test - y_test))
    testing_losses.append(test_loss.item())

    # print intermediate losses for certain iterations (0.5 point)
    if i % 100 == 1: 
        print('Iteration: %04d | Training loss: %f | Testing loss: %f' % \
              (i, loss.data, test_loss.data))


#training and testing loss curves
plt.figure(figsize=(10, 5))
plt.plot(training_losses, label='Training Loss')
plt.plot(testing_losses, label='Testing Loss')
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Training and Testing Loss Curves')
plt.legend()
plt.show()
# Out:
# Iteration: 0001 | Training loss: 111.684509 | Testing loss: 99.961731
# Iteration: 0101 | Training loss: 95.370987 | Testing loss: 85.702682
# Iteration: 0201 | Training loss: 80.673332 | Testing loss: 71.995476
# Iteration: 0301 | Training loss: 67.267136 | Testing loss: 59.202023
# Iteration: 0401 | Training loss: 55.876984 | Testing loss: 50.140537
# Iteration: 0501 | Training loss: 47.558350 | Testing loss: 45.024326
# Iteration: 0601 | Training loss: 42.769268 | Testing loss: 41.461281
# Iteration: 0701 | Training loss: 38.945511 | Testing loss: 38.119511
# Iteration: 0801 | Training loss: 35.249046 | Testing loss: 34.668282
# Iteration: 0901 | Training loss: 31.559599 | Testing loss: 31.124775
# Iteration: 1001 | Training loss: 27.881550 | Testing loss: 27.583271
# Iteration: 1101 | Training loss: 24.260550 | Testing loss: 24.106314
# Iteration: 1201 | Training loss: 20.732525 | Testing loss: 20.713625
# Iteration: 1301 | Training loss: 17.342487 | Testing loss: 17.438877
# Iteration: 1401 | Training loss: 14.186709 | Testing loss: 14.361412
# Iteration: 1501 | Training loss: 11.377895 | Testing loss: 11.644112
# Iteration: 1601 | Training loss: 9.060178 | Testing loss: 9.357069
# Iteration: 1701 | Training loss: 7.457843 | Testing loss: 7.753255
# Iteration: 1801 | Training loss: 6.663883 | Testing loss: 6.960916
# Iteration: 1901 | Training loss: 6.382972 | Testing loss: 6.715015
# Iteration: 2001 | Training loss: 6.268697 | Testing loss: 6.632047
# Iteration: 2101 | Training loss: 6.202830 | Testing loss: 6.602546
# Iteration: 2201 | Training loss: 6.154574 | Testing loss: 6.592975
# Iteration: 2301 | Training loss: 6.116422 | Testing loss: 6.588254
# Iteration: 2401 | Training loss: 6.084363 | Testing loss: 6.584406
# Iteration: 2501 | Training loss: 6.056124 | Testing loss: 6.575843
# Iteration: 2601 | Training loss: 6.030532 | Testing loss: 6.562787
# Iteration: 2701 | Training loss: 6.006597 | Testing loss: 6.550803
# Iteration: 2801 | Training loss: 5.983780 | Testing loss: 6.536564
# Iteration: 2901 | Training loss: 5.961689 | Testing loss: 6.521410
# Iteration: 3001 | Training loss: 5.940100 | Testing loss: 6.497651
# Iteration: 3101 | Training loss: 5.918864 | Testing loss: 6.476139
# Iteration: 3201 | Training loss: 5.897907 | Testing loss: 6.455864
# Iteration: 3301 | Training loss: 5.877202 | Testing loss: 6.431195
# Iteration: 3401 | Training loss: 5.856685 | Testing loss: 6.408713
# Iteration: 3501 | Training loss: 5.836343 | Testing loss: 6.385101
# Iteration: 3601 | Training loss: 5.816132 | Testing loss: 6.362904
# Iteration: 3701 | Training loss: 5.796089 | Testing loss: 6.338281
# Iteration: 3801 | Training loss: 5.776271 | Testing loss: 6.314183
# Iteration: 3901 | Training loss: 5.756625 | Testing loss: 6.290333
# Iteration: 4001 | Training loss: 5.737157 | Testing loss: 6.267872
# Iteration: 4101 | Training loss: 5.717869 | Testing loss: 6.245637
# Iteration: 4201 | Training loss: 5.698744 | Testing loss: 6.223042
# Iteration: 4301 | Training loss: 5.679786 | Testing loss: 6.200813
# Iteration: 4401 | Training loss: 5.660944 | Testing loss: 6.179037
# Iteration: 4501 | Training loss: 5.642292 | Testing loss: 6.155934
# Iteration: 4601 | Training loss: 5.623744 | Testing loss: 6.134838
# Iteration: 4701 | Training loss: 5.605373 | Testing loss: 6.113907
# Iteration: 4801 | Training loss: 5.587192 | Testing loss: 6.092676
# Iteration: 4901 | Training loss: 5.569198 | Testing loss: 6.072657
# Iteration: 5001 | Training loss: 5.551257 | Testing loss: 6.050984
# Iteration: 5101 | Training loss: 5.533413 | Testing loss: 6.030499
# Iteration: 5201 | Training loss: 5.515693 | Testing loss: 6.010210
# Iteration: 5301 | Training loss: 5.498118 | Testing loss: 5.992242
# Iteration: 5401 | Training loss: 5.480676 | Testing loss: 5.971565
# Iteration: 5501 | Training loss: 5.463340 | Testing loss: 5.950403
# Iteration: 5601 | Training loss: 5.446219 | Testing loss: 5.931089
# Iteration: 5701 | Training loss: 5.429190 | Testing loss: 5.912502
# Iteration: 5801 | Training loss: 5.412217 | Testing loss: 5.893337
# Iteration: 5901 | Training loss: 5.395372 | Testing loss: 5.874294
# Iteration: 6001 | Training loss: 5.378630 | Testing loss: 5.855751
# Iteration: 6101 | Training loss: 5.361949 | Testing loss: 5.837462
# Iteration: 6201 | Training loss: 5.345436 | Testing loss: 5.819323
# Iteration: 6301 | Training loss: 5.329051 | Testing loss: 5.803140
# Iteration: 6401 | Training loss: 5.312725 | Testing loss: 5.785164
# Iteration: 6501 | Training loss: 5.296537 | Testing loss: 5.767783
# Iteration: 6601 | Training loss: 5.280487 | Testing loss: 5.753039
# Iteration: 6701 | Training loss: 5.264535 | Testing loss: 5.737023
# Iteration: 6801 | Training loss: 5.248701 | Testing loss: 5.722528
# Iteration: 6901 | Training loss: 5.233007 | Testing loss: 5.706210
# Iteration: 7001 | Training loss: 5.217494 | Testing loss: 5.691410
# Iteration: 7101 | Training loss: 5.202111 | Testing loss: 5.676187
# Iteration: 7201 | Training loss: 5.186831 | Testing loss: 5.660678
# Iteration: 7301 | Training loss: 5.171696 | Testing loss: 5.644027
# Iteration: 7401 | Training loss: 5.156730 | Testing loss: 5.627736
# Iteration: 7501 | Training loss: 5.141912 | Testing loss: 5.613652
# Iteration: 7601 | Training loss: 5.127265 | Testing loss: 5.598926
# Iteration: 7701 | Training loss: 5.112722 | Testing loss: 5.584536
# Iteration: 7801 | Training loss: 5.098346 | Testing loss: 5.569264
# Iteration: 7901 | Training loss: 5.084090 | Testing loss: 5.557423
# Iteration: 8001 | Training loss: 5.069949 | Testing loss: 5.543987
# Iteration: 8101 | Training loss: 5.055932 | Testing loss: 5.530367
# Iteration: 8201 | Training loss: 5.042138 | Testing loss: 5.516960
# Iteration: 8301 | Training loss: 5.028463 | Testing loss: 5.502912
# Iteration: 8401 | Training loss: 5.014872 | Testing loss: 5.491182
# Iteration: 8501 | Training loss: 5.001489 | Testing loss: 5.476567
# Iteration: 8601 | Training loss: 4.988240 | Testing loss: 5.465726
# Iteration: 8701 | Training loss: 4.975145 | Testing loss: 5.454407
# Iteration: 8801 | Training loss: 4.962125 | Testing loss: 5.442355
# Iteration: 8901 | Training loss: 4.949254 | Testing loss: 5.429058
# Iteration: 9001 | Training loss: 4.936541 | Testing loss: 5.414829
# Iteration: 9101 | Training loss: 4.923976 | Testing loss: 5.403021
# Iteration: 9201 | Training loss: 4.911532 | Testing loss: 5.393237
# Iteration: 9301 | Training loss: 4.899200 | Testing loss: 5.381175
# Iteration: 9401 | Training loss: 4.886991 | Testing loss: 5.370148
# Iteration: 9501 | Training loss: 4.874951 | Testing loss: 5.359679
# Iteration: 9601 | Training loss: 4.863078 | Testing loss: 5.348761
# Iteration: 9701 | Training loss: 4.851310 | Testing loss: 5.337505
# Iteration: 9801 | Training loss: 4.839760 | Testing loss: 5.326808
# Iteration: 9901 | Training loss: 4.828284 | Testing loss: 5.316893

# %%
# As our model contains a 3 dimensionsional input, we will only plot the relationship between the first variable 'tv' and the target.
# Again plot the train and test data (from Part1), and add a line where the slope and axis intercept are taken from the model parameters w and b
# (0.5 point)

# YOUR CODE HERE

w_tv = model.w[0].item()  
b = model.b.item()        

tv_values = x_train[:, 0].detach().cpu().numpy()  
sales_pred_line = w_tv * tv_values + b

plt.figure(figsize=(10, 5))
plt.scatter(x_train[:, 0].detach().cpu().numpy(), y_train.detach().cpu().numpy(), color='blue', label='Training Data')
plt.scatter(x_test[:, 0].detach().cpu().numpy(), y_test.detach().cpu().numpy(), color='red', label='Testing Data')
plt.plot(tv_values, sales_pred_line, color='green', label='Model Prediction Line', linewidth=2)
plt.xlabel('TV Advertising Spend')
plt.ylabel('Sales')
plt.title('Relationship Between TV Advertising and Sales')
plt.legend()
plt.show()
